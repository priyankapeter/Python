# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
abc=pd.read_csv("Downloads//myexcel - myexcel.csv.csv")
abc
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
print(abc.describe())
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
print(abc.isnull().sum())
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
abc.duplicated().sum()
# Out:
# 0

# %%
random_heights = np.random.randint(150, 181, size=len(abc))
abc['height'] = random_heights
print(abc['height'].describe())
print(abc['height'].isnull().sum()) 
print(abc.head())
# Out:
# count    458.000000
# mean     165.827511
# std        9.094613
# min      150.000000
# 25%      158.000000
# 50%      167.000000
# 75%      174.000000
# max      180.000000
# Name: height, dtype: float64
# 0
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary  height
# 0              Texas  7730337.0     150
# 1          Marquette  6796117.0     154
# 2  Boston University        NaN     162
# 3      Georgia State  1148640.0     162
# 4                NaN  5000000.0     168

# %%
employee = pd.DataFrame(abc)
employee.columns = employee.columns.str.strip()
team_counts=employee["Team"].value_counts()
print(team_counts)
percentage_split=(team_counts/len(employee))*100
print("\Percentage of Spliting Across Teams:\n\n")
print(percentage_split)
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64
# ...

# %%
plt.figure(figsize=(10,5))
team_counts.plot(kind="bar",color="yellow")
plt.title("Distribution of Employees Across Teams")
plt.xlabel("Team")
plt.ylabel("number of Employees")
plt.legend()
plt.grid(axis="y",linestyle="--")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
abc=pd.read_csv(file_path)
positions=abc["Position"].unique()
position_groups={}

for position in positions:
    position_groups[position]=abc[abc["Position"]==position]
for position,employees in position_groups.items():
    print (f"\nEmployees in Positon '{position}':")
    print(employees)
# Out:
# Employees in Positon 'PG':
#               Name                    Team  Number Position  Age  Height  \
# 0    Avery Bradley          Boston Celtics       0       PG   25  06-Feb
# 8     Terry Rozier          Boston Celtics      12       PG   22  06-Feb
# 9     Marcus Smart          Boston Celtics      36       PG   22  06-Apr
# 11   Isaiah Thomas          Boston Celtics       4       PG   27  05-Sep
# 19    Jarrett Jack           Brooklyn Nets       2       PG   32  06-Mar
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2       PG   30  06-Jan
# 443     Trey Burke               Utah Jazz       3       PG   23  06-Jan
# 445     Dante Exum               Utah Jazz      11       PG   20  06-Jun
# 453   Shelvin Mack               Utah Jazz       8       PG   26  06-Mar
# 454      Raul Neto               Utah Jazz      25       PG   24  06-Jan
#
#      Weight         College     Salary
# ...

# %%
xyz=abc["Position"]
age=abc["Age"]
salary=abc["Salary"]
plt.hist(xyz)
plt.xlabel("Position")
plt.ylabel("Number of Employees")
plt.show()

# %%
abc[abc["Position"]=="SG"]
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 2        John Holland          Boston Celtics      30       SG   27  06-May
# 3         R.J. Hunter          Boston Celtics      28       SG   22  06-May
# 12        Evan Turner          Boston Celtics      11       SG   27  06-Jul
# 13        James Young          Boston Celtics      13       SG   20  06-Jun
# 15   Bojan Bogdanovic           Brooklyn Nets      44       SG   27  06-Aug
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28  06-May
# 437     C.J. McCollum  Portland Trail Blazers       3       SG   24  06-Apr
# 438      Luis Montero  Portland Trail Blazers      44       SG   23  06-Jul
# 444        Alec Burks               Utah Jazz      10       SG   24  06-Jun
# 449       Rodney Hood               Utah Jazz       5       SG   23  06-Aug
#
#      Weight            College     Salary
# ...

# %%
abc[abc["Position"]=="C"]
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     7-0
# 10   Jared Sullinger          Boston Celtics       7        C   24  06-Sep
# 14      Tyler Zeller          Boston Celtics      44        C   26     7-0
# 23       Brook Lopez           Brooklyn Nets      11        C   28     7-0
# 27        Henry Sims           Brooklyn Nets      14        C   26  06-Oct
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26  06-Nov
# 447      Rudy Gobert               Utah Jazz      27        C   23  07-Jan
# 455     Tibor Pleiss               Utah Jazz      21        C   26  07-Mar
# 456      Jeff Withey               Utah Jazz      24        C   26     7-0
# 457         Priyanka               Utah Jazz      34        C   25  07-Mar
#
#      Weight         College      Salary
# ...

# %%
abc[abc["Position"]=="SF"]
# Out:
#                        Name                    Team  Number Position  Age  \
# 1               Jae Crowder          Boston Celtics      99       SF   25
# 32   Thanasis Antetokounmpo         New York Knicks      43       SF   23
# 33          Carmelo Anthony         New York Knicks       7       SF   32
# 35         Cleanthony Early         New York Knicks      11       SF   25
# 42             Lance Thomas         New York Knicks      42       SF   28
# ..                      ...                     ...     ...      ...  ...
# 428         Al-Farouq Aminu  Portland Trail Blazers       8       SF   25
# 432        Maurice Harkless  Portland Trail Blazers       4       SF   23
# 448          Gordon Hayward               Utah Jazz      20       SF   26
# 450              Joe Ingles               Utah Jazz       2       SF   28
# 451           Chris Johnson               Utah Jazz      23       SF   26
#
#      Height  Weight        College      Salary
# ...

# %%
abc[abc["Position"]=="PG"]
# Out:
#               Name                    Team  Number Position  Age  Height  \
# 0    Avery Bradley          Boston Celtics       0       PG   25  06-Feb
# 8     Terry Rozier          Boston Celtics      12       PG   22  06-Feb
# 9     Marcus Smart          Boston Celtics      36       PG   22  06-Apr
# 11   Isaiah Thomas          Boston Celtics       4       PG   27  05-Sep
# 19    Jarrett Jack           Brooklyn Nets       2       PG   32  06-Mar
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2       PG   30  06-Jan
# 443     Trey Burke               Utah Jazz       3       PG   23  06-Jan
# 445     Dante Exum               Utah Jazz      11       PG   20  06-Jun
# 453   Shelvin Mack               Utah Jazz       8       PG   26  06-Mar
# 454      Raul Neto               Utah Jazz      25       PG   24  06-Jan
#
#      Weight         College     Salary
# 0       180           Texas  7730337.0
# ...

# %%
abc[abc["Position"]=="PF"]
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 4       Jonas Jerebko          Boston Celtics       8       PF   29  06-Oct
# 5        Amir Johnson          Boston Celtics      90       PF   29  06-Sep
# 6       Jordan Mickey          Boston Celtics      55       PF   21  06-Aug
# 24   Chris McCullough           Brooklyn Nets       1       PF   21  06-Nov
# 25        Willie Reed           Brooklyn Nets      33       PF   26  06-Oct
# ..                ...                     ...     ...      ...  ...     ...
# 435    Meyers Leonard  Portland Trail Blazers      11       PF   24  07-Jan
# 441       Noah Vonleh  Portland Trail Blazers      21       PF   20  06-Sep
# 442     Trevor Booker               Utah Jazz      33       PF   28  06-Aug
# 446    Derrick Favors               Utah Jazz      15       PF   24  06-Oct
# 452        Trey Lyles               Utah Jazz      41       PF   20  06-Oct
#
#      Weight       College      Salary
# ...

# %%
abc=pd.read_csv(file_path)
age_bins=[20,30,40,50,60,70]
age_labels=["20-29","30-39","40-49","50-59","60-69"]
abc["Age Groups"]=pd.cut(abc["Age"], bins=age_bins,labels=age_labels,right=False)
age_group_counts=abc["Age Groups"].value_counts()
predominant_age_group=age_group_counts.idxmax()
print("Predominant Age Group Among Employees:", predominant_age_group)
# Out:
# Predominant Age Group Among Employees: 20-29

# %%
sns.distplot(age)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14640\2912825138.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age)
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
abc= pd.read_csv(file_path)
salary_expenditure_by_team = abc.groupby('Team')['Salary'].sum()
salary_expenditure_by_position = abc.groupby('Position')['Salary'].sum()
team_highest_expenditure = salary_expenditure_by_team.idxmax()
position_highest_expenditure = salary_expenditure_by_position.idxmax()
print("Team with the Highest Salary Expenditure:", team_highest_expenditure)
print("Position with the Highest Salary Expenditure:", position_highest_expenditure)
# Out:
# Team with the Highest Salary Expenditure: Cleveland Cavaliers
# Position with the Highest Salary Expenditure: C

# %%
sns.boxplot(salary)
plt.show()

# %%
abc["Position"].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(X='Age', Y='Salary', abc="abc")
plt.title('Correlation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# sns.catplot(x=="Age",y=="Salary",abc=="abc", kind=="bar")
# plt.show()

# %%
abc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
abc.loc[:,abc.isnull().any()]
# Out:
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 2 columns]
